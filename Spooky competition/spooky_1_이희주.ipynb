# %% [markdown]
# - competition/dataset : [https://www.kaggle.com/c/spooky-author-identification](https://www.kaggle.com/c/spooky-author-identification)
# - date : 2021/03/08
# - original : [https://www.kaggle.com/arthurtok/spooky-nlp-and-topic-modelling-tutorial](https://www.kaggle.com/arthurtok/spooky-nlp-and-topic-modelling-tutorial)

# %% [markdown]
# ## Spooky NLP and Topic Modelling tutorial

# %% [markdown]
# **✏ 필사 1회**

# %% [markdown]
# ### Introduction
# 이 노트북에서는 Spooky Author 데이터 셋을 토픽 모델링하는 매우 기초적인 시도를 할 것입니다. 토픽 모델링은 추상적인 주제나 텍스트 말뭉치의 문서와 단어에 기초한 토픽을 밝히기 위한 과정입니다. Latent Dirichlet Allocation(LDA)와 Non-negative Matrix Factorization(NMF), 두 가지 토픽 모델링 기술을 보일 것입니다. 또한 학습 모델을 에측할 때 유용하게 활용되어야 할 Toknization, Stemming, Vectorization과 같은 Natural Language Processing을 소개할 수 있는 기회를 가질 것입니다.
#
# 순서는 크게 다음과 같습니다:
# 1. **Exploratory Data Analysis(EDA) and Wordclouds** - 단어 빈도 수 등과 같은 간단한 통계를 생성하고 일부 단어에 대해 워드클라우드를 생성하여 데이터 분석
# 2. **Natural Language Processing(NLP) with Natural Language Toolkit(NLTK)** - Term Frequencies(TF)와 the Inverse Document Frequencies(TF-IDF)를 통해 텍스트 토큰화, 불용어 제거, 스테밍, 벡터화와 같은 기본적인 텍스트 처리 방법 소개
# 3. **Topic Modelling with LDA and NNMF** - 두 가지 토픽 모델링 기술 Latent Dirichlet Allocation(LDA)와 Non-negative Matrix Factorization(NMF) 구현

# %%
import base64
import numpy as np
import pandas as pd

# Plotly imports
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

# Other import
from collections import Counter
from imageio import imread
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
train = pd.read_csv('data/train.csv')

# %% [markdown]
# ### 1. The Authors and their works EDA

# %%
train.head(3)
# Out:
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP

# %% [markdown]
# 대회 페이지에 의하면 세 개의 작가 이니셜이 있습니다:
#
# 1. **EAP - Edgar Allen Poe**: 미스터리, 추리, 암울한 이야기에 대한 단편 소설이나 시를 쓰는 미국 작가 - 가장 유명한 시는 "The Raven"이며 탐정 소설 장르의 선구자로 널리 알려져있음
# 2. **HPL - HP Lovecraft**: 공포 소설 작가로 가장 잘 알려졌으며, 가장 유명한 이야기는 악명 높은 생물체인 "Cthulhu"의 신화를 중심으로 전개됨 - 문어 머리와 날개가 있는 사람의 몸이 혼합된 키메라
# 3. **MWS - Mary Shelly**: 소설가, 드라마 작가, 여행작가, 전기 작가 등 문학적인 분야의 모든 곳에 관여. 일명 "The Modern Prometheus"인 과학자 프랑켄슈타인이 그의 이름과 관련된 괴물을 만드는 프랑켄슈타인의 고전적인 이야기로 유명

# %%
print(train.shape)
# Out:
# (19579, 3)

# %% [markdown]
# #### Summary statics of the training set
# 작가별 항목 분포 등 기본적인 통계를 시각화해볼 수 있습니다. 이를 위해 시각화 라이브러리인 Plotly를 불러와 몇 가지 막대 그래프를 나타내보겠습니다.

# %%
z = {'EAP':'Edgar Allen Poe',
     'MWS':'Mary Shelly',
     'HPL':'HP Lovecraft'}
data = [go.Bar(
    x=train['author'].map(z).unique(),
    y=train['author'].value_counts().values,
    marker=dict(colorscale='Jet',
               color=train['author'].value_counts().values),
    text='Text entries attributed to Author'
)]
layout = go.Layout(title='Target variable distribution')
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='basic-bar')

# %%
# 공백 기준 분할, 열로 분배, 데이터를 일렬로 늘어놓음, 각 단어별 빈도 수 계산
all_words = train['text'].str.split(expand=True).unstack().value_counts()
data = [go.Bar(
    x=all_words.index.values[2:50],
    y=all_words.values[2:50],
    marker=dict(colorscale='Jet',
                color=all_words.values[2:100]),
    text='Word counts'
)]

layout = go.Layout(title="Top 50 (Uncleaned) word frequencies in the training dataset")
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='basic-bar')

# %% [markdown]
# 단어 빈도 플롯에 나타나는 단어 중 이상한 점을 찾으셨나요? 이 단어들이 실제로 Mary Shelley가 그녀의 이야기에서 독자들에게 묘사하고자 하는 주제와 개념에 대해 잘 말해주고 있나요?
#
# 이 단어들은 모두 어디서나 찾을 수 있는 너무 흔히 있는 단어입니다. 세 작가들에 의한 spooky 이야기와 소설뿐만 아니라 신문, 어린이 책, 종교 서적 등 모든 영어 문서들에 존재합니다. 따라서 테이블에 별로 도움이 되지 않는 흔히 발생되는 모든 단어들을 제거하기 위해 먼저 데이터셋을 전처리할 방법을 찾아야 합니다.

# %% [markdown]
# #### WordClouds to visualize each author's work
# 자연어 처리에 관해 데이터 사이언티스트에게 가장 유용한 시각화 툴 중 하나는 "워드 클라우드"입니다. 워드클라우드는 이름에서 알 수 있듯이 문서나 책을 구성하며 각 단어의 크기가 문서에서의 해당 단어 빈도와 비례하는 구별된 단어들의 혼합으로 만들어진 이미지입니다. 실제 책이나 문서를 다루는 대신 우리의 단어는 'text' 컬럼에서 간단하게 추출할 수 있습니다.

# %% [markdown]
# ##### Store the text of each author in a Python list
# 우리는 먼저 각각 Edgar Allen Poe, HP Lovecraft, Mary Shelley의 텍스트들이 저장된 세 개의 다른 파이썬 리스트를 만듭니다.

# %%
eap = train[train['author'] == 'EAP']['text'].values
hpl = train[train['author'] == 'HPL']['text'].values
mws = train[train['author'] == 'MWS']['text'].values

# %% [markdown]
# 파이썬의 wordcloud 모듈을 사용하여 워드클라우드를 만들겠습니다.

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# 그러나 일반 워드클라우드를 생성하는 것은 지루하기 때문에 사진을 가져와서 사진의 윤곽을 워드클라우드의 마스크로 사용하는 방법을 소개하고자 합니다. 제가 선택한 사진은 작가들을 가장 잘 대표할 수 있다고 느낀 사진들입니다:
# 1. The Raven for Edgar Allen Poe
# 2. Octopus Cthulu-thingy for HP Lovecraft
# 3. Frankenstein for Mary Shelly
#
# 제 방식에 익숙한 독자들은 이미 이 기술을 알고 있겠지만 kaggle에 이미지를 로드하는 방법은 일종의 기능 해킹입니다. 먼저 사용하고자 하는 이미지의 Base64 인코딩을 얻은 후, 해당 인코딩을 사용하여 이미지를 노트북에 다시 변환합니다. 아래의 셀은 사용할 세 이미지의 Base64 인코딩 내용을 포함하고 있습니다만, 긴 텍스트 길이로 노트북을 오염시키고 싶지 않기 때문에 숨겨 놓겠습니다.

# %%
eap_64 = b'...'

# %%
hpl_64 = b'...'

# %%
mws_64 = b'...'

# %% [markdown]
# 이미지를 디코딩하기 위해 'codecs' 모듈을 임포트하고 새로운 이미지로 저장합니다. 한번 이미지가 저장되면 마스크로 간단하게 로드할 수 있습니다.

# %%
import codecs
# EAP의 마스크 생성
f1 = open('data/eap.png', 'wb')
f1.write(codecs.decode(eap_64, 'base64'))
f1.close()
img1 = imread('data/eap.png')
hcmask1 = img1

f2 = open('data/mws.png', 'wb')
f2.write(codecs.decode(mws_64, 'base64'))
f2.close()
img2 = imread('data/mws.png')
hcmask2 = img2

f3 = open('data/hpl.png', 'wb')
f3.write(codecs.decode(hpl_64, 'base64'))
f3.close()
img3 = imread('data/hpl.png')
hcmask3 = img3

# %%
# Mary Shelly에 대한 Frankenstein 워드클라우드
plt.figure(figsize=(16, 13))
wc = WordCloud(background_color='black', max_words=10000,
               mask=hcmask2, stopwords=STOPWORDS, max_font_size=40)
wc.generate(' '.join(mws))
plt.title("Mary Shelley (Frankenstein's Monster)", fontsize=20)
plt.imshow(wc.recolor(colormap='viridis', random_state=17), alpha=0.98)
plt.axis('off')
plt.show()

# %%
# Edgar Allen Poe에 대한 The Raven 워드클라우드
plt.figure(figsize=(16, 13))
wc = WordCloud(background_color='black', max_words=10000,
               mask=hcmask1, stopwords=STOPWORDS, max_font_size=40)
wc.generate(' '.join(eap))
plt.title('Edgar Allen Poe (The Raven)', fontsize=20)
plt.imshow(wc.recolor(colormap='PuBu', random_state=17), alpha=0.98)
plt.axis('off')
plt.show()

# %%
# HP LoveCraft에 대한 Cthulhu/squidy 워드클라우드
plt.figure(figsize=(16, 13))
wc = WordCloud(background_color='black', max_words=10000,
               mask=hcmask3, stopwords=STOPWORDS, max_font_size=40)
wc.generate(' '.join(hpl))
plt.title('HP Lovecraft (Cthulhu-Squidy)', fontsize=20)
plt.imshow(wc.recolor(colormap='Pastel2', random_state=17), alpha=0.98)
plt.axis('off')
plt.show()

# %% [markdown]
# HP Lovecraft가 선호하는 단어는 dream, time, strange, past, ancient와 같이 저자가 유명했던 숨겨진 정신과 난해한 본성뿐만 아니라 악명 높은 생물체 Cthulhu, 관련된 고대 숭배와 의식에 대한 언급으로 반향에 대한 주제로 반향을 불러일으키는 것 같습니다.
#
# 반면에, Mary Shelley의 단어는 friend, fear, hope, spirit과 같이 긍정에서 부정까지 이르는 도덕의 본능과 주제와 관련되어 있습니다.
#
# 그러나 워드 클라우드에서 볼 수 있듯이 아직도 어울리지 않는 단어들이 몇 개 있습니다. us, go, he와 같은 단어들은 어디서나 흔히 볼 수 있는 것으로 보입니다.

# %% [markdown]
# ### 2. Natural Language Processing (NLP)
# 1. **Tokenization**: 텍스트를 각각의 단어로 분리
# 2. **Stopwords**: 너무 빈번하게 등장하는 단어의 경우 텍스트와의 관련성을 찾는데 도움이 되지 않기 때문에 제거
# 3. **Stemming**: 같은 의미를 갖는 단어는 결합
# 4. **Vectorization**: 텍스트를 벡터 포멧으로 변경. 가장 간단한 방법 중 하나는 말뭉치의 각 문서나 텍스트에 대해 행렬을 만드는 bag-of-words 접근 방법. 가장 간단한 형태에서 이 행렬은 단어의 빈도 수를 저장하며 raw text의 벡터화라고 부름

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# #### 2-1. Tokenization

# %%
# 텍스트의 첫 번째 요소를 문자열로 저장
first_text = train['text'].values[0]
print(first_text)
print('-'*80)
print(first_text.split(' '))
# Out:
# This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.
# --------------------------------------------------------------------------------
# ['This', 'process,', 'however,', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon;', 'as', 'I', 'might', 'make', 'its', 'circuit,', 'and', 'return', 'to', 'the', 'point', 'whence', 'I', 'set', 'out,', 'without', 'being', 'aware', 'of', 'the', 'fact;', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall.']

# %%
first_text_list = nltk.word_tokenize(first_text)
print(first_text_list)
# Out:
# ['This', 'process', ',', 'however', ',', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon', ';', 'as', 'I', 'might', 'make', 'its', 'circuit', ',', 'and', 'return', 'to', 'the', 'point', 'whence', 'I', 'set', 'out', ',', 'without', 'being', 'aware', 'of', 'the', 'fact', ';', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall', '.']

# %% [markdown]
# #### 2-2. Stopword Removal

# %%
stopwords = nltk.corpus.stopwords.words('english')
len(stopwords)
# Out:
# 179

# %%
first_text_list_cleaned = [word for word in first_text_list if word.lower() not in stopwords]
print(first_text_list_cleaned)
print('-'*80)
print('Length of original list: {0} words\n'
      'Length of list after stopwords removal: {1} words'
      .format(len(first_text_list), len(first_text_list_cleaned)))
# Out:
# ['process', ',', 'however', ',', 'afforded', 'means', 'ascertaining', 'dimensions', 'dungeon', ';', 'might', 'make', 'circuit', ',', 'return', 'point', 'whence', 'set', ',', 'without', 'aware', 'fact', ';', 'perfectly', 'uniform', 'seemed', 'wall', '.']
# --------------------------------------------------------------------------------
# Length of original list: 48 words
# Length of list after stopwords removal: 28 words

# %% [markdown]
# #### 2-3. Stemming and Lemmatization

# %%
stemmer = nltk.stem.PorterStemmer()

print('The stemmed form of running is: {}'.format(stemmer.stem('running')))
print('The stemmed form of runs is: {}'.format(stemmer.stem('runs')))
print('The stemmed form of run is: {}'.format(stemmer.stem('run')))
# Out:
# The stemmed form of running is: run
# The stemmed form of runs is: run
# The stemmed form of run is: run

# %%
print('The stemmed form of leaves is: {}'.format(stemmer.stem('leaves')))
# Out:
# The stemmed form of leaves is: leav

# %% [markdown]
# ##### Lemmatization to the rescue
# 위와 같은 경우를 해결하기 위해 lemmatization을 사용합니다. 그러나 stemmer와 달리 데이터를 lemmatizing하는 것은 실제 사전이나 어휘를 기반으로 단어를 줄이는 것이 목표이기 대문에 어휘적 의미가 없는 단어를 줄여주지는 않습니다.

# %%
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
print('The lemmatize form of leaves is: {}'.format(lemm.lemmatize('leaves')))
# Out:
# The lemmatize form of leaves is: leaf

# %% [markdown]
# #### 2-4. Vectorizing Raw Text

# %% [markdown]
# ##### The Bag of Words approach

# %%
# 문장 정의
sentence = ['I love to eat Burgers', 'I love to eat Fries']
vectorizer = CountVectorizer(min_df=0)
sentence_transform = vectorizer.fit_transform(sentence)

# %% [markdown]
# ##### Fitting the vectorizer to the dataset

# %%
print('The features are:\n {}'.format(vectorizer.get_feature_names()))
print('\nThe vectorized array looks like:\n {}'.format(sentence_transform.toarray()))
# Out:
# The features are:
#  ['burgers', 'eat', 'fries', 'love', 'to']
#
# The vectorized array looks like:
#  [[1 1 0 1 1]
#  [0 1 1 1 1]]

# %%
sentence_transform
# Out:
# <2x5 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ##### Sparce matrix vector outputs

# %% [markdown]
# ### 3. Topic modelling
# 1. **Latent Dirichlet Allocation**: 각 주제를 각 단어에 서로 다른 가중치로 할당하여 데이터 셋에 잠재된 토픽을 발견하는 확률적 생성 모델
# 2. **Non-negative Matrix Factorization**: 입력 행렬을 가져와서 해당 행렬을 두 개의 다른 행렬로 근사화 (행렬 값은 음수가 아님)

# %%
# 상위 단어들을 출력하기 위한 함수
def print_top_words(models, feature_names, n_top_words):
    for i, topic in enumerate(models.components_):
        message = '\nTopic #{}:'.format(i)
        message += ' '.join([feature_names[i] for i in topic.argsort()[:-n_top_words-1:-1]])
        print(message)
        print('-'*80)

# %% [markdown]
# #### 3-1. Putting all the preprocessing steps together

# %% [markdown]
# ##### Extending the CountVectorizer class with a lemmatizer

# %%
lemm = WordNetLemmatizer()
class LemmaCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(LemmaCountVectorizer, self).build_analyzer()
        return lambda doc: (lemm.lemmatize(w) for w in analyzer(doc))

# %%
# 전체 훈련 텍스트를 리스트로 저장
text = list(train['text'].values)
tf_vectorizer = LemmaCountVectorizer(max_df=0.95, min_df=2, stop_words='english', decode_error='ingore')
tf = tf_vectorizer.fit_transform(text)

# %% [markdown]
# ##### Revisiting our Term frequencies

# %%
feature_names = tf_vectorizer.get_feature_names()
count_vec = np.asarray(tf.sum(axis=0)).ravel()
zipped = list(zip(feature_names, count_vec))
x, y = (list(x) for x in zip(*sorted(zipped, key=lambda x: x[1], reverse=True)))
# 상위 15개와 하위 15개
Y = np.concatenate([y[0:15], y[-16:-1]])
X = np.concatenate([x[0:15], x[-16:-1]])

# 상위 50개 단어 시각화
data = [go.Bar(
    x=x[:50],
    y=y[:50],
    marker=dict(colorscale='Jet', color=y[:50]),
    text='Word counts'
)]
layout = go.Layout(title='Top 50 word frequencies after preprocessing')
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='basic-bar')

# 하위 100개 단어 시각화
data = [go.Bar(
    x=x[-100:],
    y=y[-100:],
    marker=dict(colorscale='Portland', color=y[-100:]),
    text='Word counts'
)]
layout = go.Layout(title='Bottom 100 word frequencies after preprocessing')
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='basic-bar')

# %% [markdown]
# #### 3-2. Latent Dirichlet Allocation

# %%
lda = LatentDirichletAllocation(
    n_components=11, max_iter=5, learning_method='online', 
    learning_offset=50., random_state=0
)
lda.fit(tf)
# Out:
# LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                           max_iter=5, n_components=11, random_state=0)

# %% [markdown]
# ##### Topics generated by LDA

# %%
n_top_words = 40
print('Topics in LDA model:')
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topics in LDA model:
#
# Topic #0:mean night fact young return great human looking wonder countenance difficulty greater wife finally set possessed regard struck perceived act society law health key fearful mr exceedingly evidence carried home write lady various recall accident force poet neck conduct investigation
# --------------------------------------------------------------------------------
#
# Topic #1:death love raymond hope heart word child went time good man ground evil long misery replied filled passion bed till happiness memory heavy region year escape spirit grief visit doe story beauty die plague making influence thou letter appeared power
# --------------------------------------------------------------------------------
#
# ...

# %%
first_topic = lda.components_[0]
second_topic = lda.components_[1]
third_topic = lda.components_[2]
fourth_topic = lda.components_[3]

# %%
first_topic.shape
# Out:
# (13781,)

# %% [markdown]
# ##### Word Cloud visualizations of the topics

# %%
first_topic_words = [tf_feature_names[i] for i in first_topic.argsort()[:-50-1:-1]]
second_topic_words = [tf_feature_names[i] for i in second_topic.argsort()[:-50-1:-1]]
third_topic_words = [tf_feature_names[i] for i in third_topic.argsort()[:-50-1:-1]]
fourth_topic_words = [tf_feature_names[i] for i in fourth_topic.argsort()[:-50-1:-1]]

# %% [markdown]
# ##### Word cloud of First Topic

# %%
# 카테고리 데이터프레임의 값에 대한 워드클라우드 생성
firstcloud = WordCloud(stopwords=STOPWORDS, background_color='black',
                       width=2500, height=1800).generate(' '.join(first_topic_words))
plt.imshow(firstcloud)
plt.axis('off')
plt.show()

# %%
# 카테고리 데이터프레임의 값에 대한 워드클라우드 생성
secondcloud = WordCloud(stopwords=STOPWORDS, background_color='black',
                        width=2500, height=1800).generate(' '.join(second_topic_words))
plt.imshow(secondcloud)
plt.axis('off')
plt.show()

# %%
# 카테고리 데이터프레임의 값에 대한 워드클라우드 생성
thirdcloud = WordCloud(stopwords=STOPWORDS, background_color='black',
                        width=2500, height=1800).generate(' '.join(third_topic_words))
plt.imshow(thirdcloud)
plt.axis('off')
plt.show()

# %%
# 카테고리 데이터프레임의 값에 대한 워드클라우드 생성
fourthcloud = WordCloud(stopwords=STOPWORDS, background_color='black',
                        width=2500, height=1800).generate(' '.join(fourth_topic_words))
plt.imshow(fourthcloud)
plt.axis('off')
plt.show()
